# %%
import lux_tickers as lx
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import seaborn as sns
# Out:
# ('Authorization Token:', u'657e35aab43979907288ab7337d271d5', 'Expires:', u'20180803T160625Z')

# %%
lux_brands = ['epa:ker','epa:mc','hk:1913','private:christianlouboutin']

# %%
df = lx.multi_tickers(lux_brands)
# Out:
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# 57001

# %%
df['Ticker Symbol'].unique()
# Out:
# array([u'epa:mc', u'hk:1913', u'epa:ker'], dtype=object)

# %%
df['Screen Name'].unique()
# Out:
# array([u'MoetUSA', u'HennessyUS', u'mYquem', u'belvederevodka',
#        u'Thomas_Pink_', u'givenchy', u'ChandonUSA', u'MAKEUPFOREVERUS',
#        u'capementelle', u'ChandonWine', u'FreshBeauty', u'Fendi',
#        u'berluti', u'Ardbeg', u'NOWNESS', u'LVMH', u'Chaumet',
#        u'ParfumsGivenchy', u'Hublot', u'grandeepicerie', u'TAGHeuer',
#        u'NewtonVineyard', u'Krug', u'InvestirFr', u'marcjacobs',
#        u'SamaritainePro', u'BenefitBeauty', u'NudeSkincare', u'Guerlain',
#        u'CloudyBay', u'LouisVuitton', u'DFSOfficial', u'kenzo',
#        u'Cdesarts', u'LoeweOfficial', u'NKirkwoodLondon', u'Chandon_Ar',
#        u'VeuveClicquot', u'Bulgariofficial', u'radioclassique',
#        u'LesEchos', u'EmilioPucci', u'FrancketFils', u'Dior',
#        u'lebonmarche', u'TheGlenmorangie', u'Prada', u'Car_Shoe',
#        u'MIUMIUofficial', u'ThomasPinkUSA', u'qeelinjewellery',
#        u'BALENCIAGA', u'cobragolf', u'DodoJewels', u'jrwatches',
#        u'ulysse_nardin', u'gucci', u'KeringGroup', u'StellaMcCartney',
#        u'BottegaVeneta', u'GirardPerregaux', u'PUMAGolf', u'YSL',
#        u'Boucheron', u'Brioni_Official', u'Volcom', u'RIMOWA',
#        u'Echos_Solutions', u'louisvuittonjp', u'LouisvuittonRu',
#        u'wing_eu', u'louisvuitton_au', u'tracktl', u'ardbeg_com',
#        u'Acqua_di_Parma', u'KrugChampagneUS'], dtype=object)

# %%
df
# Out:
#     Ticker Symbol Entity Name  Unique ID As Of Date      Screen Name  \
# 0          epa:mc   453221057   53850195 2018-08-02          MoetUSA
# 1          epa:mc   461577457   53845335 2018-08-02       HennessyUS
# 2          epa:mc   132156570   53850196 2018-08-02           mYquem
# 3          epa:mc    24201942   53850227 2018-08-02   belvederevodka
# 4          epa:mc   404049418   53850198 2018-08-02     Thomas_Pink_
# 5          epa:mc   274040176   53850199 2018-08-02         givenchy
# 6          epa:mc    27976258   53850222 2018-08-02       ChandonUSA
# 7          epa:mc    26035198   53850200 2018-08-02  MAKEUPFOREVERUS
# 8          epa:mc    17954053   53850201 2018-08-02     capementelle
# 9          epa:mc  2309305927   53850202 2018-08-02      ChandonWine
# 10         epa:mc   532345947   53850234 2018-08-02      FreshBeauty
# 11         epa:mc   114796408   53850205 2018-08-02            Fendi
# 12         epa:mc  1449650078   53850206 2018-08-02          berluti
# 13         epa:mc    36330998   53850210 2018-08-02           Ardbeg
# 14         epa:mc    14718073   53850207 2018-08-02          NOWNESS
# 15         epa:mc   558606074   53850213 2018-08-02             LVMH
# 16         epa:mc    24868793   53850209 2018-08-02          Chaumet
# 17         epa:mc   404039438   53850211 2018-08-02  ParfumsGivenchy
# 18         epa:mc    26714575   53850214 2018-08-02           Hublot
# 19         epa:mc  2388801186   53850215 2018-08-02   grandeepicerie
# 20         epa:mc    92245322   53850208 2018-08-02         TAGHeuer
# 21         epa:mc    42974037   53850216 2018-08-02   NewtonVineyard
# 22         epa:mc   324034364   53850233 2018-08-02             Krug
# 23         epa:mc    92055625   53850217 2018-08-02       InvestirFr
# 24         epa:mc   109702885   53850218 2018-08-02       marcjacobs
# 25         epa:mc  1137438421   53850219 2018-08-02   SamaritainePro
# 26         epa:mc    18220767   53850241 2018-08-02    BenefitBeauty
# 27         epa:mc    35734322   53850221 2018-08-02     NudeSkincare
# 28         epa:mc   538899195   53850225 2018-08-02         Guerlain
# 29         epa:mc    88544253   53850226 2018-08-02        CloudyBay
# ..            ...         ...        ...        ...              ...
# 974        epa:mc   453221057     507064 2015-11-30          MoetUSA
# 975        epa:mc   461577457     507065 2015-11-30       HennessyUS
# 976        epa:mc   453221057     504305 2015-11-29          MoetUSA
# 977        epa:mc   461577457     504306 2015-11-29       HennessyUS
# 978        epa:mc   453221057     501613 2015-11-28          MoetUSA
# 979        epa:mc   461577457     501614 2015-11-28       HennessyUS
# 980        epa:mc   453221057     498993 2015-11-27          MoetUSA
# 981        epa:mc   461577457     498994 2015-11-27       HennessyUS
# 982        epa:mc   453221057     496408 2015-11-26          MoetUSA
# 983        epa:mc   461577457     496409 2015-11-26       HennessyUS
# 984        epa:mc   453221057     492597 2015-11-25          MoetUSA
# 985        epa:mc   461577457     492599 2015-11-25       HennessyUS
# 986        epa:mc   453221057     492596 2015-11-24          MoetUSA
# 987        epa:mc   461577457     492598 2015-11-24       HennessyUS
# 988        epa:mc   453221057     488786 2015-11-23          MoetUSA
# 989        epa:mc   461577457     488787 2015-11-23       HennessyUS
# 976  Consumer Goods  Personal Goods
# 977  Consumer Goods  Personal Goods
# 978  Consumer Goods  Personal Goods
# 979  Consumer Goods  Personal Goods
# 980  Consumer Goods  Personal Goods
# 981  Consumer Goods  Personal Goods
# 982  Consumer Goods  Personal Goods
# 983  Consumer Goods  Personal Goods
# 984  Consumer Goods  Personal Goods
# 985  Consumer Goods  Personal Goods
# 986  Consumer Goods  Personal Goods
# 987  Consumer Goods  Personal Goods
# 988  Consumer Goods  Personal Goods
# 989  Consumer Goods  Personal Goods
# 990  Consumer Goods  Personal Goods
# 991  Consumer Goods  Personal Goods
# 992  Consumer Goods  Personal Goods
# 993  Consumer Goods  Personal Goods
# 994  Consumer Goods  Personal Goods
# 995  Consumer Goods  Personal Goods
# 996  Consumer Goods  Personal Goods
# 997  Consumer Goods  Personal Goods
# 998  Consumer Goods  Personal Goods
# 999  Consumer Goods  Personal Goods
# 0    Consumer Goods  Personal Goods
# 1    Consumer Goods  Personal Goods
# 2    Consumer Goods  Personal Goods
# 3    Consumer Goods  Personal Goods
#
# [57004 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
class FixedOrderFormatter(ScalarFormatter):
    """Formats axis ticks using scientific notation with a constant order of 
    magnitude"""
    def __init__(self, order_of_mag=0, useOffset=True, useMathText=False):
        self._order_of_mag = order_of_mag
        ScalarFormatter.__init__(self, useOffset=useOffset, 
                                 useMathText=useMathText)
    def _set_orderOfMagnitude(self, range):
        """Over-riding this to avoid having orderOfMagnitude reset elsewhere"""
        self.orderOfMagnitude = self._order_of_mag

# %%
def twitter_followers(df,col,name1):
    #input: dataframe, usernames to compare (printed in describe_data)
    #example: compare_likes(data,'jackinthebox','burgerking')
    sns.set(style="ticks")
    fig, ax1 = plt.subplots(figsize=(12,8))
    fig.suptitle('Twitter Followers Over Time',y=1)

    color = 'tab:red'
    ax1.set_xlabel('Time (months)',labelpad=15,fontsize=15)
    ax1.set_ylabel(name1, color=color,labelpad=15,fontsize=15)
    df_1 = df[df['Screen Name'] == name1]
    ax1.plot(df_1['As Of Date'],df_1[col], color=color)
    ax1.tick_params(axis='y', labelcolor=color,labelsize=11)
    ax1.tick_params(axis='x', labelsize=11)
    ax1.ticklabel_format(axis='y',style='sci')
    ax1.yaxis.set_major_formatter(FixedOrderFormatter(6))
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

# %%
twitter_followers(df,'Followers','marcjacobs')

# %%
twitter_followers(df,'Followers','Dior')

# %%
twitter_followers(df,'Followers','LouisVuitton')

# %%
twitter_followers(df,'Followers','gucci')

# %%
twitter_followers(df,'Followers','YSL')

# %%
twitter_followers(df,'Followers','Prada')

# %%
twitter_followers(df,'Followers','BALENCIAGA')

# %%
df_twi = df

# %%
# %store df_twi
# Out:
# Stored 'df_twi' (DataFrame)
