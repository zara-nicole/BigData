# %%
import social_facebook as sf

# %%
df = sf.multi_tickers(['nyse:mcd','nyse:qsr'])
# Out:
# 1001
# 2001
# 3001
# 4001
# 5001

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
#sf.compare_col_date(df,'Likes','2016-09','McDonaldsUS','wendys')

# %%
sf.compare_col_date(df,'Likes','2015-12','McDonaldsUS','burgerking')

# %%
sf.compare_col_date(df,'Likes','2015-12','McDonaldsUS','burgerking')

# %%
import social_facebook as sf

# %%
sf.compare_col_date(df,'Likes','2015-12','McDonaldsUS','burgerking')
