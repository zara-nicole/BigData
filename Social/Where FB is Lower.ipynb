# %%
# %store -r my_data
# %store -r fb_data

# %%
my_data
# Out:
# {'247sports_df': year_month         2016-10   2016-11   2016-12   2017-01   2017-02   2017-03  \
#  channel
#  drudgereport.com  0.000447  0.000679  0.000344  0.000437  0.000292  0.000222
#  espn.com          0.000599  0.000465  0.000437  0.000523  0.000214  0.000634
#  facebook          0.915362  0.916056  0.910192  0.888740  0.884777  0.891798
#  google            0.000973  0.001504  0.001240  0.001925  0.001626  0.001944
#  linkedin          0.000938  0.001179  0.001248  0.001199  0.002146  0.002602
#  reddit            0.023108  0.020954  0.019783  0.036431  0.036889  0.029969
#  twitter           0.038343  0.041405  0.048409  0.053411  0.052390  0.051655
#  youtube           0.001676  0.002412  0.002129  0.002403  0.003852  0.004186
#  other             0.018554  0.015344  0.016219  0.014930  0.017814  0.016989
#
#  year_month         2017-04   2017-05   2017-06   2017-07   2017-08   2017-09  \
#  channel
# ...

# %%
len(fb_data)
# Out:
# 529

# %%
fb_data['2016'] = (fb_data['2016-10'] + fb_data['2016-11'] + fb_data['2016-12'])/3.0

# %%
fb_data['2017'] = (fb_data['2017-01']+fb_data['2017-02']+fb_data['2017-03']+fb_data['2017-04']+fb_data['2017-05']+fb_data['2017-06']+fb_data['2017-07']+fb_data['2017-08']+fb_data['2017-09']+fb_data['2017-10'] + fb_data['2017-11'] + fb_data['2017-12'])/12.0

# %%
fb_data['2018'] = (fb_data['2018-01'] + fb_data['2018-02'] + fb_data['2018-03'])/3.0

# %%
fb_avg=fb_data[['2016','2017','2018']]

# %%
fb_avg[fb_avg['2016']>fb_avg['2018']]
# Out:
# year_month             2016       2017        2018
# giphy              0.724909   0.584925     0.40404
# citibankonline     0.504342   0.475986    0.417706
# coursehero         0.555123   0.468689    0.437652
# steampowered       0.314185   0.281362    0.258501
# mlb                0.423758   0.345515    0.274729
# thrillist          0.845255   0.845819     0.80308
# github             0.239873   0.225489    0.201839
# retailmenot        0.799057   0.626887    0.419771
# theroot            0.758118   0.755606    0.657506
# indeed              0.50412   0.449882    0.379655
# patch              0.843075   0.841956    0.808489
# jezebel            0.718157   0.664439    0.550443
# scribd             0.618074   0.547868    0.388581
# hulu               0.385581   0.398192    0.315855
# bettycrocker       0.331803   0.241019    0.289778
# sciencedirect      0.487088   0.439927    0.382244
# ncaa               0.594299   0.442747    0.324027
# ...

# %%
# out of 529 websites, 448 had a negative change in fb from 16-18
# 413 had a negative change in fb from 16-17
# 449 had a negative change in fb from 17-18
