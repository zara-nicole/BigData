# %%
import pandas as pd

# %%
# %store -r my_data_nan

# %%
#want to find top 5 share holders for each month for each site

for key,df in my_data_nan.iteritems():
    #for each dataframe, sort each column high to low
    
        df = df.sort_values(by='2018-03',ascending=False)
        print key
        print df[:10][['2018-03']]
        
        
        
        
        
        #new_df = df.loc['facebook'].to_frame().reset_index().T
        #new_df.columns = new_df.loc['year_month']
        #new_df = new_df.drop(['year_month']) # (1,18)
        #fb_data=fb_data.add(new_df)
# Out:
# sendgrid_df
# year_month      2018-03
# channel
# youtube        0.339590
# linkedin       0.299615
# facebook       0.278478
# soundcloud     0.072021
# orion.kz       0.010296
# balatarin.com       NaN
# getpocket           NaN
# google              NaN
# instagram           NaN
# mail.aol.com        NaN
# giphy_df
# year_month    2018-03
# channel
# reddit       0.542629
# facebook     0.396932
# youtube      0.010937
# twitter      0.006747
# whatsapp     0.001790
# i.imgur.com  0.000654
# vk           0.000397
# pinterest    0.000272
# google       0.000183
# imgur.com    0.000181
# bedbathandbeyond_df
# year_month   2018-03
# channel
# facebook    0.336406
# youtube     0.264586
# pinterest   0.172811
# reddit      0.122557
# twitter     0.028470
# instagram   0.007638
# linkedin    0.005045
# getpocket   0.004336
# whatsapp    0.001915
# google      0.001678
# citibankonline_df
# year_month        2018-03
# channel
# facebook         0.464630
# youtube          0.362450
# ...

# %%
my_data_nan.keys()[2]
# Out:
# 'bedbathandbeyond_df'

# %%
df_1 = my_data_nan.values()[2]
df_1
# Out:
# year_month                    2016-10   2016-11   2016-12   2017-01   2017-02  \
# channel
# 1st.media                         NaN       NaN       NaN       NaN       NaN
# ablog.typepad.com                 NaN       NaN       NaN       NaN       NaN
# acdsee.com                   0.000310       NaN       NaN       NaN       NaN
# ahalife.com                  0.000302       NaN       NaN       NaN       NaN
# amazon                       0.001022  0.006839  0.003965  0.000570  0.004508
# answers.yahoo.com                 NaN       NaN  0.001308       NaN       NaN
# apartmenttherapy.com              NaN       NaN       NaN       NaN       NaN
# apracticalwedding.com             NaN       NaN       NaN       NaN       NaN
# aristeguinoticias.com             NaN       NaN  0.000970       NaN       NaN
# ask.fm                            NaN  0.002699       NaN       NaN       NaN
# badoo.com                         NaN       NaN       NaN       NaN       NaN
# ...

# %%
df_1 = df_1.sort_values(by='2018-03',ascending=False)
df_1[:10][['2018-03']]
# Out:
# year_month   2018-03
# channel
# facebook    0.336406
# youtube     0.264586
# pinterest   0.172811
# reddit      0.122557
# twitter     0.028470
# instagram   0.007638
# linkedin    0.005045
# getpocket   0.004336
# whatsapp    0.001915
# google      0.001678

# %%
fb_data = pd.DataFrame(index=['facebook'] , columns=['2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04',
 '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11',
 '2017-12', '2018-01' ,'2018-02' ,'2018-03']).fillna(0)

for key,df in my_data.iteritems():
    if 'facebook' in df.index:
        new_df = df.loc['facebook'].to_frame().reset_index().T
        new_df.columns = new_df.loc['year_month']
        new_df = new_df.drop(['year_month']) # (1,18)
        fb_data=fb_data.add(new_df)

# %%
#facebook dropped from top share to 2nd/3rd etc.
