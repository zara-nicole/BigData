# %%
import lux_tickers as lx
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import seaborn as sns

# %%
lux_brands = ['epa:ker','epa:mc','hk:1913','private:christianlouboutin']

# %%
df = lx.multi_tickers(lux_brands)
# Out:
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001

# %%
df.head()
# Out:
#   Ticker Symbol       Entity Name  Unique ID As Of Date  \
# 0        epa:mc   225366520988977   38539754 2018-07-27
# 1        epa:mc   297418100301448   38542742 2018-07-27
# 2       epa:ker  1624734651118721   38542739 2018-07-27
# 3        epa:mc   218779764832411   38539744 2018-07-27
# 4        epa:mc   192989290715208   38539750 2018-07-27
#
#                   Username  Checkins  Has App  Were Here Count    Likes  \
# 0  starboardcruiseservices       208    False              208     2767
# 1      NicholasKirkwoodLtd       233    False              235    41308
# 2  ChristopherKaneOfficial         0    False                0    16902
# 3             francketfils       446    False              446     2887
# 4                 Givenchy      2609    False                0  2788453
#
#    Talking About Count       Facebook Id        Date Added      Date Updated  \
# 0                   23   225366520988977  20180727T021046Z  20180727T021046Z
# ...

# %%
df['Ticker Symbol'].unique()
# Out:
# array([u'epa:mc', u'epa:ker', u'hk:1913', u'private:christianlouboutin'], dtype=object)

# %%
df['Username'].unique()
# Out:
# array([u'starboardcruiseservices', u'NicholasKirkwoodLtd',
#        u'ChristopherKaneOfficial', u'francketfils', u'Givenchy', u'LOEWE',
#        u'AlexanderMcQueen', u'keringgroup', u'Prada', u'Pomellato',
#        u'lagrandeepicerie', u'OfficialUlysseNardinUSA', u'LoroPiana',
#        u'lasamaritaine.official', u'givenchybeauty.france',
#        u'DodoJewelsInternational', u'GuerlainFR', u'Berluti', u'carshoe',
#        u'nudeskincare', u'stellamccartney', u'nowness', u'Volcom',
#        u'Bulgari', u'Dior', u'DFS', u'ThomasPink', u'ysl', u'Investir.fr',
#        u'boucheron', u'lesechos', u'makeupforever', u'FredParisOfficialFR',
#        u'kenzoparis', u'UlysseNardinwatches', u'bottegaveneta', u'Fendi',
#        u'emiliopucci', u'benefitcosmetics', u'MiuMiu', u'cdesarts',
#        u'R.Classique', u'GUCCI', u'LouisVuitton', u'Balenciaga', u'edun',
#        u'Chaumet', u'Hublot', u'fresh', u'QeelinJewellery', u'sephora',
# ...

# %% [markdown]
# Tickers and associated Usernames:
# * 'epa:mc' : LVMH Moet Hennessy Louis Vuitton
#     * 'ysl'
#     * 'Balenciaga'
#     * 'Dior'
#     * 'LouisVuitton'
# * 'private:christianlouboutin' : Christian Louboutin
# * 'hk:1913' : Prada
# * 'epa: ker' : Kering
#     * 'GUCCI'
#
#     * 'marcjacobsintl'

# %%
df_fb = df[df['Username'].isin(['GUCCI','ysl','Balenciaga','Prada','Dior','LouisVuitton','marcjacobsintl','christianlouboutin'])]

# %%
df_fb['Username'].unique()
# Out:
# array([u'Prada', u'Dior', u'ysl', u'GUCCI', u'LouisVuitton', u'Balenciaga',
#        u'marcjacobsintl', u'christianlouboutin'], dtype=object)

# %%
df_fb
# Out:
#     Ticker Symbol      Entity Name  Unique ID As Of Date        Username  \
# 8         hk:1913  164637176974573   38537954 2018-07-27           Prada
# 24         epa:mc  118197471568260   38539758 2018-07-26            Dior
# 27        epa:ker     106537403849   38539735 2018-07-26             ysl
# 42        epa:ker      44596321012   38539736 2018-07-26           GUCCI
# 43         epa:mc     215138065124   38539756 2018-07-26    LouisVuitton
# 44        epa:ker  128450347241247   38539722 2018-07-26      Balenciaga
# 59         epa:mc  145598892122326   38539759 2018-07-26  marcjacobsintl
# 68        hk:1913  164637176974573   38528246 2018-07-25           Prada
# 79         epa:mc  145598892122326   38529995 2018-07-25  marcjacobsintl
# 92         epa:mc     215138065124   38529992 2018-07-24    LouisVuitton
# 93        epa:ker      44596321012   38529975 2018-07-24           GUCCI
# 110        epa:mc  118197471568260   38529994 2018-07-24            Dior
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
class FixedOrderFormatter(ScalarFormatter):
    """Formats axis ticks using scientific notation with a constant order of 
    magnitude"""
    def __init__(self, order_of_mag=0, useOffset=True, useMathText=False):
        self._order_of_mag = order_of_mag
        ScalarFormatter.__init__(self, useOffset=useOffset, 
                                 useMathText=useMathText)
    def _set_orderOfMagnitude(self, range):
        """Over-riding this to avoid having orderOfMagnitude reset elsewhere"""
        self.orderOfMagnitude = self._order_of_mag

# %%
def fb_followers(df,col,name1):
    #input: dataframe, usernames to compare (printed in describe_data)
    #example: compare_likes(data,'jackinthebox','burgerking')
    sns.set(style="ticks")
    fig, ax1 = plt.subplots(figsize=(12,8))
    fig.suptitle('Facebook Likes Over Time',y=1)

    color = 'tab:red'
    ax1.set_xlabel('Time (months)',labelpad=15,fontsize=15)
    ax1.set_ylabel(name1, color=color,labelpad=15,fontsize=15)
    df_1 = df[df['Username']==name1]
    ax1.plot(df_1['As Of Date'],df_1[col], color=color)
    ax1.tick_params(axis='y', labelcolor=color,labelsize=11)
    ax1.tick_params(axis='x', labelsize=11)
    ax1.ticklabel_format(axis='y',style='sci')
    ax1.yaxis.set_major_formatter(FixedOrderFormatter(6))
    
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

# %%
fb_followers(df_fb,'Likes','LouisVuitton')

# %%
fb_followers(df_fb,'Likes','GUCCI')

# %%
fb_followers(df_fb,'Likes','Dior')

# %%
fb_followers(df_fb,'Likes','Prada')

# %%
fb_followers(df_fb,'Likes','ysl')

# %%
fb_followers(df_fb,'Likes','christianlouboutin')

# %%
fb_followers(df_fb,'Likes','marcjacobsintl')

# %%
fb_followers(df_fb,'Likes','Balenciaga')

# %%
# %store df_fb
# Out:
# Stored 'df_fb' (DataFrame)
